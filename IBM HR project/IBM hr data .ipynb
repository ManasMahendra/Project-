# %%
import pandas as pd
import numpy as na
import matplotlib.pyplot as plt
import seaborn as sb 
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Ibm hr data\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# There is no empty columns in data set .

data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# There is no duplicate values in the data .

data.duplicated(subset=None, keep='first')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
# we see the the categorical and numerical columns .

categorical_column = []
numerical_column = []

for i in data.columns:
    if data[i].dtype == 'object':
        categorical_column.append(i)
    else:
        numerical_column.append(i)
print("categorical_column = ",categorical_column)
print("numerical_column = ",numerical_column)
# Out:
# categorical_column =  ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# numerical_column =  ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
# Task 1 - What is the  count of  employees daily rating? 
# There are the daily rating of the employees.

# %%
plt.figure(figsize= (6,4))
sb.histplot(data = data, x = 'DailyRate');

# %%
# Task 2 - Which department have the highest count of employees ?
# Research and Development have the highest count employees.

# %%
sb.countplot(x=data['Department'])
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
# Task 3 - Which Business Travel have the highest count of employees ?
# Most of the employees travel rarely .

# %%
sb.countplot(x=data['BusinessTravel'])
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='count'>

# %%
# Task 4 - Which Education Field have the highest count employees .
# Life Sciences have the highest count of employees.

# %%
sb.countplot(x=data['EducationField'])
plt.xticks(rotation=90)
plt.show()

# %%
# Task 5 - Which gender have the highest percentage.
# There are 60 % of the male employees .

# %%
ind=data['Gender'].value_counts().index
val=data['Gender'].value_counts().values
plt.pie(x=val,labels=ind,autopct='%.2f%%')
plt.show()

# %%
# Task 6 - What is the highest percentage of Marital Status ?
# There are 45.78 % of employees are married .

# %%
fig, ax = plt.subplots(figsize= (6,4))
ax = sb.countplot(x=data['MaritalStatus'])
for bar in ax.patches:                                             
    percentage =f"{round(bar.get_height() /data.shape[0]*100, 2)}%"         
                                                                    
    x = bar.get_x() + bar.get_width() /2                           
    y = bar.get_height()                                           
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )

# %%
# Task 7 - Which Job Role have the highest percentage of employees .
# There are 22.18 % of employees are in  Sales Executive job role .

# %%
ax = sb.countplot(x=data['JobRole'])
for bar in ax.patches:                                             
    percentage =f"{round(bar.get_height() /data.shape[0]*100, 2)}%"         
                                                                    
    x = bar.get_x() + bar.get_width() /2                           
    y = bar.get_height()                                           
    ax.annotate(percentage, (x, y), va = "bottom", ha ="center" )
plt.xticks(rotation=90)
plt.show()

# %%
# Task 8 -  What is the BusinessTravel wise  Attrition ?
#  Travel rarely have the highest number of yes and no .

# %%
sb.countplot(x=data['BusinessTravel'],hue=data['Attrition'])
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='count'>

# %%
# Task 9 - What is the Gender wise Attrition ?
# Male have the highest number of yes and no .

# %%
sb.countplot(x=data['Gender'],hue=data['Attrition'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Task 10 - what is Gender wise overtime ?
# There is very less number of employees who are doing overtime .

# %%
sb.countplot(x=data['OverTime'],hue=data['Gender'])
# Out:
# <Axes: xlabel='OverTime', ylabel='count'>

# %%
# Task 11 - Which Education Field have the highest count of employees as per gender .
# Life Sciences have the highest count of employees as per gender.

# %%
sb.countplot(x=data['EducationField'],hue=data['Gender'])
plt.xticks(rotation=90)
plt.show()

# %%
# Task 12 - Which department have the highest count of gender .
# Research and Development Department have the highest count of employees as per gerder .

# %%
sb.countplot(x=data['Department'],hue=data['Gender'])
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
# Task 13 - Which gender have the highest Distance From Home .
# 2 have the highest count of employees as per gender .

# %%
sb.countplot(x=data['DistanceFromHome'],hue=data['Gender'])
# Out:
# <Axes: xlabel='DistanceFromHome', ylabel='count'>

# %%
# Task 14 - less than 30 years at the company .
#  Which year have the highest count of employees .
# 5 years have the highest count of employees.

# %%
y=data[data['YearsAtCompany']<30]
sb.countplot(x=y['YearsAtCompany'])
# Out:
# <Axes: xlabel='YearsAtCompany', ylabel='count'>

# %%
# Task  15 -

# %%
x=data[data['Age']<=50]
sb.boxplot(x=x['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
# Task  16 - What is attrition wise hourly rate of employees ?

# %%
sb.boxplot(x=data['HourlyRate'],y=data['Attrition'])
# Out:
# <Axes: xlabel='HourlyRate', ylabel='Attrition'>

# %%
# Task 17 - What is Gender wise monthly income of employees ?
# Male have the highest monthly income .

# %%
sb.boxplot(x=data['MonthlyIncome'],y=data['Gender'])
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Gender'>
